# %%
# | hide
# | eval: false
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# | hide
from lobster_tools.preprocessing import Data, Event, Lobster

# %%
# | hide
import pandas as pd
from IPython.core.getipython import get_ipython

# %%
# | hide
def _set_df_rendering_to_html():
    "Set the rendering of Pandas DataFrames to HTML so that README.md is rendered by GitHub correctly."
    html_formatter = get_ipython().display_formatter.formatters["text/html"]

    html_formatter.for_type(
        pd.DataFrame,
        lambda df: df.to_html(
            max_rows=pd.get_option("display.max_rows"), show_dimensions=False
        ),
    )


_set_df_rendering_to_html()

# %% [markdown]
# # Getting started
#
# > A python package for working with [LOBSTER data](https://lobsterdata.com/), the limit order book data from [Nasdaq](https://www.nasdaq.com/).

# %% [markdown]
# ## Install

# %% [markdown]
# ```sh
# $ pip install lobster-tools
# ```

# %% [markdown]
# ## How to use

# %%
data = Data(ticker="AMZN", date_range="2012-06-21", load="both")
lobster = Lobster(data=data)
# Out:
# /nfs/home/nicolasp/anaconda3/envs/lob/lib/python3.11/site-packages/lobster_tools/preprocessing.py:320: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[]' has dtype incompatible with int8, please explicitly cast to a compatible dtype first.
#   df.loc[df.event.eq(Event.ORIGINAL_TRADING_HALT.value), "event"] = df.loc[

# %%
lobster.messages.head()
# Out:
#                                        time  event  order_id  size   price  \
# datetime
# 2012-06-21 09:30:00.017459617  34200.017460      5         0     1  223.82
# 2012-06-21 09:30:00.189607670  34200.189608      1  11885113    21  223.81
# 2012-06-21 09:30:00.189607670  34200.189608      1   3911376    20  223.96
# 2012-06-21 09:30:00.189607670  34200.189608      1  11534792   100  223.75
# 2012-06-21 09:30:00.189607670  34200.189608      1   1365373    13  224.00
#
#                                direction
# datetime
# 2012-06-21 09:30:00.017459617         -1
# 2012-06-21 09:30:00.189607670          1
# 2012-06-21 09:30:00.189607670         -1
# 2012-06-21 09:30:00.189607670          1
# 2012-06-21 09:30:00.189607670         -1

# %%
lobster.book.head()
# Out:
#                                ask_price_1  ask_size_1  bid_price_1  \
# datetime
# 2012-06-21 09:30:00.017459617       223.95       100.0       223.18
# 2012-06-21 09:30:00.189607670       223.95       100.0       223.81
# 2012-06-21 09:30:00.189607670       223.95       100.0       223.81
# 2012-06-21 09:30:00.189607670       223.95       100.0       223.81
# 2012-06-21 09:30:00.189607670       223.95       100.0       223.81
#
#                                bid_size_1  ask_price_2  ask_size_2  \
# datetime
# 2012-06-21 09:30:00.017459617       100.0       223.99       100.0
# 2012-06-21 09:30:00.189607670        21.0       223.99       100.0
# 2012-06-21 09:30:00.189607670        21.0       223.96        20.0
# 2012-06-21 09:30:00.189607670        21.0       223.96        20.0
# 2012-06-21 09:30:00.189607670        21.0       223.96        20.0
#
#                                bid_price_2  bid_size_2  ask_price_3  \
# datetime
# 2012-06-21 09:30:00.017459617       223.07       200.0       224.00
# 2012-06-21 09:30:00.189607670       223.18       100.0       224.00
# 2012-06-21 09:30:00.189607670       223.18       100.0       223.99
# 2012-06-21 09:30:00.189607670       223.75       100.0       223.99
# 2012-06-21 09:30:00.189607670       223.75       100.0       223.99
#
#                                ask_size_3  bid_price_3  bid_size_3  \
# datetime
# 2012-06-21 09:30:00.017459617       220.0       223.04       100.0
# 2012-06-21 09:30:00.189607670       220.0       223.07       200.0
# 2012-06-21 09:30:00.189607670       100.0       223.07       200.0
# 2012-06-21 09:30:00.189607670       100.0       223.18       100.0
# 2012-06-21 09:30:00.189607670       100.0       223.18       100.0
#
#                                ask_price_4  ask_size_4  bid_price_4  \
# datetime
# 2012-06-21 09:30:00.017459617       224.25       100.0       223.00
# 2012-06-21 09:30:00.189607670       224.25       100.0       223.04
# 2012-06-21 09:30:00.189607670       224.00       220.0       223.04
# 2012-06-21 09:30:00.189607670       224.00       220.0       223.07
# 2012-06-21 09:30:00.189607670       224.00       233.0       223.07
#
#                                bid_size_4  ask_price_5  ask_size_5  \
# datetime
# 2012-06-21 09:30:00.017459617        10.0       224.40       547.0
# 2012-06-21 09:30:00.189607670       100.0       224.40       547.0
# 2012-06-21 09:30:00.189607670       100.0       224.25       100.0
# 2012-06-21 09:30:00.189607670       200.0       224.25       100.0
# 2012-06-21 09:30:00.189607670       200.0       224.25       100.0
#
#                                bid_price_5  bid_size_5
# datetime
# 2012-06-21 09:30:00.017459617       222.62       100.0
# 2012-06-21 09:30:00.189607670       223.00        10.0
# 2012-06-21 09:30:00.189607670       223.00        10.0
# 2012-06-21 09:30:00.189607670       223.04       100.0
# 2012-06-21 09:30:00.189607670       223.04       100.0

# %%
(
    lobster.messages.query(f"event == {Event.HIDDEN_EXECUTION.value}")
    .query(f"direction == -1")
    .head()
)
# Out:
#                                        time  event  order_id  size   price  \
# datetime
# 2012-06-21 09:30:00.017459617  34200.017460      5         0     1  223.82
# 2012-06-21 09:30:00.372779672  34200.372780      5         0   100  223.84
# 2012-06-21 09:30:00.375671205  34200.375671      5         0   100  223.84
# 2012-06-21 09:30:00.383971366  34200.383971      5         0   100  223.86
# 2012-06-21 09:30:00.385815710  34200.385816      5         0   100  223.86
#
#                                direction
# datetime
# 2012-06-21 09:30:00.017459617         -1
# 2012-06-21 09:30:00.372779672         -1
# 2012-06-21 09:30:00.375671205         -1
# 2012-06-21 09:30:00.383971366         -1
# 2012-06-21 09:30:00.385815710         -1
