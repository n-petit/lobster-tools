# %%
#| hide
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# | hide
from lobster_tools.preprocessing import *
from lobster_tools.querying import *

# %% [markdown]
# # Getting started 🦞
#
# > A python package for working with [LOBSTER data](https://lobsterdata.com/), the limit order book data from Nasdaq.

# %% [markdown]
# ## Install

# %% [markdown]
# ::: {.panel-tabset}
#
# #### pip
#
# ```sh
# pip install -U lobster-tools
# ```
#
# #### conda
#
# ```sh
# conda install -c conda-forge? lobster-tools
# ```
#
# :::

# %% [markdown]
# ## How to use

# %%
lobster = load_lobster(ticker="GE", date_range="2019-01-02", load="both")

lobster.messages.head()
# Out:
#                                event  order_id  size    price  direction  \
# datetime
# 2019-01-02 03:08:36.253659641      7         0     0   0.0001         -1
# 2019-01-02 04:00:00.030994898      1     11818   400   7.0100          1
# 2019-01-02 04:00:00.031785491      1     12390    53  10.9900         -1
# 2019-01-02 04:00:00.032366928      1     12838    60  11.9700         -1
# 2019-01-02 04:00:00.033012154      1     13226    60  10.9500         -1
#
#                               ticker
# datetime
# 2019-01-02 03:08:36.253659641     GE
# 2019-01-02 04:00:00.030994898     GE
# 2019-01-02 04:00:00.031785491     GE
# 2019-01-02 04:00:00.032366928     GE
# 2019-01-02 04:00:00.033012154     GE

# %%
(lobster.messages.pipe(query_by_event, event="execution").pipe(get_buy).head())
# Out:
#                                event  order_id  size  price  direction ticker
# datetime
# 2019-01-02 09:30:00.108595257      4   6837778   100   7.46          1     GE
# 2019-01-02 09:30:00.108595257      4   6837786   200   7.46          1     GE
# 2019-01-02 09:30:00.208825584      4   6885658   200   7.46          1     GE
# 2019-01-02 09:30:00.208825584      4   6885666   300   7.46          1     GE
# 2019-01-02 09:30:00.208825584      4   6885674   200   7.46          1     GE

# %%
lobster.book.head()
# Out:
#                                ask_price_1  ask_size_1  bid_price_1  \
# datetime
# 2019-01-02 03:08:36.253659641          NaN         NaN          NaN
# 2019-01-02 04:00:00.030994898          NaN         NaN         7.01
# 2019-01-02 04:00:00.031785491        10.99        53.0         7.01
# 2019-01-02 04:00:00.032366928        10.99        53.0         7.01
# 2019-01-02 04:00:00.033012154        10.95        60.0         7.01
#
#                                bid_size_1  ask_price_2  ask_size_2  \
# datetime
# 2019-01-02 03:08:36.253659641         NaN          NaN         NaN
# 2019-01-02 04:00:00.030994898       400.0          NaN         NaN
# 2019-01-02 04:00:00.031785491       400.0          NaN         NaN
# 2019-01-02 04:00:00.032366928       400.0        11.97        60.0
# 2019-01-02 04:00:00.033012154       400.0        10.99        53.0
#
#                                bid_price_2  bid_size_2  ask_price_3  \
# datetime
# 2019-01-02 03:08:36.253659641          NaN         NaN          NaN
# 2019-01-02 04:00:00.030994898          NaN         NaN          NaN
# 2019-01-02 04:00:00.031785491          NaN         NaN          NaN
# 2019-01-02 04:00:00.032366928          NaN         NaN          NaN
# 2019-01-02 04:00:00.033012154          NaN         NaN        11.97
#
#                                ask_size_3  ...  bid_price_8  bid_size_8  \
# datetime                                   ...
# 2019-01-02 03:08:36.253659641         NaN  ...          NaN         NaN
# 2019-01-02 04:00:00.030994898         NaN  ...          NaN         NaN
# 2019-01-02 04:00:00.031785491         NaN  ...          NaN         NaN
# 2019-01-02 04:00:00.032366928         NaN  ...          NaN         NaN
# 2019-01-02 04:00:00.033012154        60.0  ...          NaN         NaN
#
#                                ask_price_9  ask_size_9  bid_price_9  \
# datetime
# 2019-01-02 03:08:36.253659641          NaN         NaN          NaN
# 2019-01-02 04:00:00.030994898          NaN         NaN          NaN
# 2019-01-02 04:00:00.031785491          NaN         NaN          NaN
# 2019-01-02 04:00:00.032366928          NaN         NaN          NaN
# 2019-01-02 04:00:00.033012154          NaN         NaN          NaN
#
#                                bid_size_9  ask_price_10  ask_size_10  \
# datetime
# 2019-01-02 03:08:36.253659641         NaN           NaN          NaN
# 2019-01-02 04:00:00.030994898         NaN           NaN          NaN
# 2019-01-02 04:00:00.031785491         NaN           NaN          NaN
# 2019-01-02 04:00:00.032366928         NaN           NaN          NaN
# 2019-01-02 04:00:00.033012154         NaN           NaN          NaN
#
#                                bid_price_10  bid_size_10
# datetime
# 2019-01-02 03:08:36.253659641           NaN          NaN
# 2019-01-02 04:00:00.030994898           NaN          NaN
# 2019-01-02 04:00:00.031785491           NaN          NaN
# 2019-01-02 04:00:00.032366928           NaN          NaN
# 2019-01-02 04:00:00.033012154           NaN          NaN
#
# [5 rows x 40 columns]
